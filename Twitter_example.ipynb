# %% [markdown]
# # Problem 1 - Twitter

# %% [markdown]
# This exercise introduces collection of Social Media data and working with semi-structured data in JSON format.

# %% [markdown]
# Twitter is a large source of social media data including the Twitter feed and the social network structure. The data on each tweet is semi-structured (in JSON) and dominated by metadata. The total size of each tweet is around 5-6K, which is significantly more than 140 characters dedicated to the actual text.

# %% [markdown]
# <p>Twitter provides application developers with an API (Application Program Interface) that allows applications identify trending topics, access user info (for example, user timeline, lists of followers and friends), perform search queries, stream a subset of the entire Twitter feed in real time (which is sometimes referred to as “sipping from a fire hose”) and perform many other functions. Twitter API conforms to REST architecture. REST stands for Representational State Transfer and is typically associated with 4 operations of HTTP protocol: GET, PUT, POST, and DELETE. While it is possible to access each aspect of Twitter API in terms of these operations, it is usually more convenient to use libraries that implement “wrappers” around them. One such library is a Python package twitter. For more information on REST architecture, see</p>
#
# <p><a href="http://www.infoq.com/articles/rest-introduction">A Brief Introduction to REST</a></p>
# <p><a href="http://net.tutsplus.com/tutorials/other/a-beginners-introduction-to-http-and-rest/">A Beginner’s Guide to HTTP and REST</a></p>
# <p>Twitter API documentation can be found at  <a href="https://dev.twitter.com/docs">https://dev.twitter.com/docs</a></p>

# %% [markdown]
# For accessing Twitter API, you need to
#
# <b> Create Your Twitter App </b>
# <p><font color='blue'><b>Step 1</b>&nbsp;</font> Go to https://dev.twitter.com</p>
# <p><font color='blue'><b>Step 2</b>&nbsp;</font> Click <em>Sign In</em>. in the top-right corner, and log in.</p>
#
# <p style="margin-left: 48px">You need to have a Twitter account.</p>
# <p style="margin-left: 48px"><font color = 'red'>Please follow MMA865 on Twitter.</font></p>
# <img style="position:absolute; top:500px; left:550px; width:120px; height:160px" src="mma865.png">
# <p><font color='blue'><b>Step 3</b>&nbsp;</font> https://apps.twitter.com.</p>

# %% [markdown]
# <p><font color='blue'><b>Step 4</b>&nbsp;</font> Click Create New App:</p>
#
# <ul>
# <li> Name <font color='red'>\*</font>: juewangMMA865 (create your own name)  </li>
# <li> Description <font color='red'>\*</font>: MMA865 Big Data </li>
# <li> Website <font color='red'>\*</font>: https://mma865.ca </li>
# <li> Callback URL <font color='red'>\*</font>: leave it blank </li>
# </ul>
# <img style="width:600px" align ="left" src="step4.png">

# %% [markdown]
# <p><font color='blue'><b>Step 5</b>&nbsp;</font> You can check your info in https://apps.twitter.com</p>
# <p><font color='blue'><b>Step 6</b>&nbsp;</font> Click <mark>Keys and Access Tokens</mark></p>
# <p style="margin-left: 48px">You will see your Consumer Key <span style="color: #ff0000">\*</span>, Consumer Secret <span style="color: #ff0000">\*</span></p>
# <p><img style="width:600px" align ="left" src="step6.png"></p>

# %% [markdown]
# <p><font color='blue'><b>Step 7</b>&nbsp;</font> Click Create my access token near the bottom of the current page</p>
# <p style="margin-left: 48px">You now have Access Token <span style="color: #ff0000">\*</span>, Access Token Secret <span style="color: #ff0000">\*</span></p>
# <img style="width:600px" align ="left" src="step7.png">

# %% [markdown]
# Assuming that all these steps are successfully completed, we can write a Python program to extract information from Twitter. For this problem, we use twitter python package; see either of the following:
# <p><a href= "http://mike.verdone.ca/twitter/">http://mike.verdone.ca/twitter/</a></p>
# <a href= "https://github.com/sixohsix/twitter/tree/master">https://github.com/sixohsix/twitter/tree/master</a>

# %% [markdown]
# ## Part I ##
# Define a Twitter OAuth login function:
#
# <blockquote>
# OAuth stands for Open Authentication.
# </blockquote>

# %% [markdown]
# Copy and paste into the fields of the code below your Consumer key, Consumer secret, Access token (into OAUTH_TOKEN), and Access token secret (into OAUTH_TOKEN_SECRET) that you get from Step 6 and 7 in **Create Your Twitter App**.

# %%
### Code Block 1-1 ###

import twitter
import urllib2
import json

def oauth_login():
    CONSUMER_KEY = 'cHzkizO8oSQCpqzdrCg3cuSga'
    CONSUMER_SECRET = 'DMC0KQDUPEtO8QSUsdwWEgaL63V1YRUR3rNaoVWq9v0nnYaKw6'
    OAUTH_TOKEN = '4796563954-DKsPi0lSoR9Re1EUjsJ8VeJJSpJt5ajpJLNOYyA'
    OAUTH_TOKEN_SECRET = 'k9WDRzqTEtFqKGfhZHHALi10DqSIFn4fZtbdpgQ3eKNKh'
    auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                               CONSUMER_KEY, CONSUMER_SECRET)
    twitter_api = twitter.Twitter(auth=auth)
    return twitter_api

# %% [markdown]
# <p>Now, let's define a function to check trends on Twitter:</p>

# %%
### Code Block 1-2 ###

def twitter_trends(twitter_api, woe_id):
    # Prefix ID with the underscore for query string parameterization.
    # Without the underscore, the twitter package appends the ID value
    # to the URL itself as a special-case keyword argument.
    return twitter_api.trends.place(_id=woe_id)

# %% [markdown]
# Now, we can log in the Twitter api by running Code Block 1-3.
# <blockquote>
# <div style="background-color: rgba(0,0,0,0.7); display:inline"><font color='white'>&nbsp;Tip 1&nbsp;<font></div>&nbsp;&nbsp;In order to run Code Block 1-3, you need to run Code 1-1 first, because Code Block 1-3 calls function ```oauth_login()``` that is defined in Code Block 1-1.
# </blockquote>

# %%
### Code Block 1-3 ###

twitter_api = oauth_login()
print twitter_api
# Out:
# <twitter.api.Twitter object at 0x0000000003AE5630>

# %% [markdown]
# Let's examine the trends around the world.
#
# <blockquote>
# <div style="background-color: rgba(0,0,0,0.7); display:inline"><font color='white'>&nbsp;Tip 2&nbsp;<font></div>&nbsp;&nbsp;In order to run Code 1-4, you need to first run Code Blocks 1-1, 1-2, and 1-3.
# </blockquote>

# %% [markdown]
# <font color='purple'><b>Question 1-1:</b></font> What's the reason for Tip 2? Hint: it should be similar to Tip 1

# %% [markdown]
# <font color='purple'><b>Write down your answer for Question 1-1 in this cell:</b></font>
#
# Tip 1 indicates that Code 1-1 is required for Code Block 1-3, as you cannot call the function oauth_login() unless you define it, which is done in Code Block 1-1. Similar to Tip 1, Tip 2 indicates that all 3 prior Code Blocks (1-1, 1-2, and 1-3) are required for Code Block 1-4. This is because the world_trends is defined as the function twitter_trends, which uses twitter_api, which is defined as oauth_login(). Therefore Code Block 1-4 is dependent on Code Blocks 1-1, 1-2 and 1-3 in order for the code to run correctly.

# %%
### Code Block 1-4 ###

try:
    WORLD_WOE_ID = 1
    world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
    print json.dumps(world_trends, indent=1)
except urllib2.URLError, e:
    print "Error", e
    #URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>
    #This error may happen if you do not have a consistent internet connection.
# Out:
# [
#  {
#   "created_at": "2016-01-16T18:21:23Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8364",
#     "query": "%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8364",
#     "tweet_volume": 131704,
#     "name": "#\u0632\u062f_\u0631\u0635\u064a\u062f\u064364",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Pel%C3%ADculasQueHeVistoMilVeces",
#     "query": "%23Pel%C3%ADculasQueHeVistoMilVeces",
#     "tweet_volume": 23325,
#     "name": "#Pel\u00edculasQueHeVistoMilVeces",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Chelsea",
#     "query": "Chelsea",
#     "tweet_volume": 295282,
#     "name": "Chelsea",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D9%83%D9%88%D8%B1%D9%8A%D8%A7_%D8%A7%D9%84%D8%B4%D9%85%D8%A7%D9%84%D9%8A%D9%87",
#     "query": "%23%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87_%D9%83%D9%88%D8%B1%D9%8A%D8%A7_%D8%A7%D9%84%D8%B4%D9%85%D8%A7%D9%84%D9%8A%D9%87",
#     "tweet_volume": 20754,
#     "name": "#\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0647_\u0643\u0648\u0631\u064a\u0627_\u0627\u0644\u0634\u0645\u0627\u0644\u064a\u0647",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SabadoDetremuraSdv",
#     "query": "%23SabadoDetremuraSdv",
#     "tweet_volume": 23720,
#     "name": "#SabadoDetremuraSdv",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TFCPSG",
#     "query": "%23TFCPSG",
#     "tweet_volume": 20472,
#     "name": "#TFCPSG",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Milagro+Sala%22",
#     "query": "%22Milagro+Sala%22",
#     "tweet_volume": 23547,
#     "name": "Milagro Sala",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Mahrez",
#     "query": "Mahrez",
#     "tweet_volume": 13271,
#     "name": "Mahrez",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Sinan+G%C3%BCm%C3%BC%C5%9F%22",
#     "query": "%22Sinan+G%C3%BCm%C3%BC%C5%9F%22",
#     "tweet_volume": null,
#     "name": "Sinan G\u00fcm\u00fc\u015f",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22I+LOVE+ZAYN%22",
#     "query": "%22I+LOVE+ZAYN%22",
#     "tweet_volume": 266735,
#     "name": "I LOVE ZAYN",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jason+Rezaian%22",
#     "query": "%22Jason+Rezaian%22",
#     "tweet_volume": 40321,
#     "name": "Jason Rezaian",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Aaliyah",
#     "query": "Aaliyah",
#     "tweet_volume": 68386,
#     "name": "Aaliyah",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Guidetti",
#     "query": "Guidetti",
#     "tweet_volume": null,
#     "name": "Guidetti",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22HOY+JUEGA+BOCA%22",
#     "query": "%22HOY+JUEGA+BOCA%22",
#     "tweet_volume": 22151,
#     "name": "HOY JUEGA BOCA",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22AVRIL+FEAT+HARRY%22",
#     "query": "%22AVRIL+FEAT+HARRY%22",
#     "tweet_volume": null,
#     "name": "AVRIL FEAT HARRY",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SomosFasDeBandinhaCoreana",
#     "query": "%23SomosFasDeBandinhaCoreana",
#     "tweet_volume": 23316,
#     "name": "#SomosFasDeBandinhaCoreana",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Bang100Milh%C3%B5es",
#     "query": "%23Bang100Milh%C3%B5es",
#     "tweet_volume": 22439,
#     "name": "#Bang100Milh\u00f5es",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FelizSabado",
#     "query": "%23FelizSabado",
#     "tweet_volume": 32715,
#     "name": "#FelizSabado",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B4%D9%86%D9%88_%D8%B1%D8%A7%D8%AD_%D9%8A%D9%82%D9%88%D9%84%D9%88%D9%86_%D8%B9%D9%86%D9%83_%D8%A8%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D9%82%D8%A8%D9%84",
#     "query": "%23%D8%B4%D9%86%D9%88_%D8%B1%D8%A7%D8%AD_%D9%8A%D9%82%D9%88%D9%84%D9%88%D9%86_%D8%B9%D9%86%D9%83_%D8%A8%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D9%82%D8%A8%D9%84",
#     "tweet_volume": 14640,
#     "name": "#\u0634\u0646\u0648_\u0631\u0627\u062d_\u064a\u0642\u0648\u0644\u0648\u0646_\u0639\u0646\u0643_\u0628\u0627\u0644\u0645\u0633\u062a\u0642\u0628\u0644",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%AA%D8%B5%D8%AF%D9%82_%D8%A8%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87_%D9%84%D9%88%D8%A7%D9%84%D8%AF%D9%8A%D9%83",
#     "query": "%23%D8%AA%D8%B5%D8%AF%D9%82_%D8%A8%D8%AA%D8%BA%D8%B1%D9%8A%D8%AF%D9%87_%D9%84%D9%88%D8%A7%D9%84%D8%AF%D9%8A%D9%83",
#     "tweet_volume": null,
#     "name": "#\u062a\u0635\u062f\u0642_\u0628\u062a\u063a\u0631\u064a\u062f\u0647_\u0644\u0648\u0627\u0644\u062f\u064a\u0643",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CBLoL",
#     "query": "%23CBLoL",
#     "tweet_volume": 11410,
#     "name": "#CBLoL",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EuPrecisoDe",
#     "query": "%23EuPrecisoDe",
#     "tweet_volume": null,
#     "name": "#EuPrecisoDe",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%E5%B0%8F%E6%B3%89%E8%8A%B1%E9%99%BD%E7%94%9F%E8%AA%95%E7%A5%AD2016",
#     "query": "%23%E5%B0%8F%E6%B3%89%E8%8A%B1%E9%99%BD%E7%94%9F%E8%AA%95%E7%A5%AD2016",
#     "tweet_volume": 275265,
#     "name": "#\u5c0f\u6cc9\u82b1\u967d\u751f\u8a95\u796d2016",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%C3%87okHo%C5%9FOlurdu",
#     "query": "%23%C3%87okHo%C5%9FOlurdu",
#     "tweet_volume": 10278,
#     "name": "#\u00c7okHo\u015fOlurdu",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ViveLaPatria",
#     "query": "%23ViveLaPatria",
#     "tweet_volume": 22645,
#     "name": "#ViveLaPatria",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MagconTourToMexico",
#     "query": "%23MagconTourToMexico",
#     "tweet_volume": null,
#     "name": "#MagconTourToMexico",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PeorQueUnPeloEnLaSopa",
#     "query": "%23PeorQueUnPeloEnLaSopa",
#     "tweet_volume": null,
#     "name": "#PeorQueUnPeloEnLaSopa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LucasLuccoNoCaldeirao",
#     "query": "%23LucasLuccoNoCaldeirao",
#     "tweet_volume": null,
#     "name": "#LucasLuccoNoCaldeirao",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B4%D9%88_%D9%85%D8%B2%D8%B9%D9%84%D9%83",
#     "query": "%23%D8%B4%D9%88_%D9%85%D8%B2%D8%B9%D9%84%D9%83",
#     "tweet_volume": null,
#     "name": "#\u0634\u0648_\u0645\u0632\u0639\u0644\u0643",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DoYourJob",
#     "query": "%23DoYourJob",
#     "tweet_volume": 53856,
#     "name": "#DoYourJob",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%EC%95%8C%ED%8B%B0%EB%8B%B9_%EC%8B%A4%EC%A0%9C%EC%84%B1%EA%B2%A9",
#     "query": "%23%EC%95%8C%ED%8B%B0%EB%8B%B9_%EC%8B%A4%EC%A0%9C%EC%84%B1%EA%B2%A9",
#     "tweet_volume": 12781,
#     "name": "#\uc54c\ud2f0\ub2f9_\uc2e4\uc81c\uc131\uaca9",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D0%94%D0%B8%D1%80%D0%B5%D0%BA%D1%88%D0%B8%D0%BE%D0%BD%D0%B5%D1%80%D1%8B%D0%97%D0%B0%D1%85%D0%B2%D0%B0%D1%82%D1%8F%D1%82%D0%92%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%83%D1%8E",
#     "query": "%23%D0%94%D0%B8%D1%80%D0%B5%D0%BA%D1%88%D0%B8%D0%BE%D0%BD%D0%B5%D1%80%D1%8B%D0%97%D0%B0%D1%85%D0%B2%D0%B0%D1%82%D1%8F%D1%82%D0%92%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%83%D1%8E",
#     "tweet_volume": null,
#     "name": "#\u0414\u0438\u0440\u0435\u043a\u0448\u0438\u043e\u043d\u0435\u0440\u044b\u0417\u0430\u0445\u0432\u0430\u0442\u044f\u0442\u0412\u0441\u0435\u043b\u0435\u043d\u043d\u0443\u044e",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EsteFinde",
#     "query": "%23EsteFinde",
#     "tweet_volume": null,
#     "name": "#EsteFinde",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%2310milyonliramolsa",
#     "query": "%2310milyonliramolsa",
#     "tweet_volume": null,
#     "name": "#10milyonliramolsa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HappyKanginDay",
#     "query": "%23HappyKanginDay",
#     "tweet_volume": 30903,
#     "name": "#HappyKanginDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ConRobertEnBatalla",
#     "query": "%23ConRobertEnBatalla",
#     "tweet_volume": 15322,
#     "name": "#ConRobertEnBatalla",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AtalantaInter",
#     "query": "%23AtalantaInter",
#     "tweet_volume": 16380,
#     "name": "#AtalantaInter",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23voleinaredetv",
#     "query": "%23voleinaredetv",
#     "tweet_volume": null,
#     "name": "#voleinaredetv",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheySayItsImpossibleBut",
#     "query": "%23TheySayItsImpossibleBut",
#     "tweet_volume": null,
#     "name": "#TheySayItsImpossibleBut",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BerxwedanSerhildanJiyane",
#     "query": "%23BerxwedanSerhildanJiyane",
#     "tweet_volume": null,
#     "name": "#BerxwedanSerhildanJiyane",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Amici15",
#     "query": "%23Amici15",
#     "tweet_volume": 42805,
#     "name": "#Amici15",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JustinMeetDalelyla",
#     "query": "%23JustinMeetDalelyla",
#     "tweet_volume": 85073,
#     "name": "#JustinMeetDalelyla",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SAvENG",
#     "query": "%23SAvENG",
#     "tweet_volume": 44561,
#     "name": "#SAvENG",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AA%D9%88%D9%8A%D8%AA%D8%B1%D8%A7%D9%88%D9%8A%D9%87_%D9%88%D9%81%D9%88%D9%84%D9%88%D8%B1%D8%B2_%D9%8A%D9%86%D8%A7%D9%8A%D8%B1",
#     "query": "%23%D8%A7%D9%84%D8%AA%D9%88%D9%8A%D8%AA%D8%B1%D8%A7%D9%88%D9%8A%D9%87_%D9%88%D9%81%D9%88%D9%84%D9%88%D8%B1%D8%B2_%D9%8A%D9%86%D8%A7%D9%8A%D8%B1",
#     "tweet_volume": null,
#     "name": "#\u0627\u0644\u062a\u0648\u064a\u062a\u0631\u0627\u0648\u064a\u0647_\u0648\u0641\u0648\u0644\u0648\u0631\u0632_\u064a\u0646\u0627\u064a\u0631",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TorinoFrosinone",
#     "query": "%23TorinoFrosinone",
#     "tweet_volume": null,
#     "name": "#TorinoFrosinone",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ESPGER",
#     "query": "%23ESPGER",
#     "tweet_volume": null,
#     "name": "#ESPGER",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AVLLEI",
#     "query": "%23AVLLEI",
#     "tweet_volume": null,
#     "name": "#AVLLEI",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BazenA%C4%9Flamak",
#     "query": "%23BazenA%C4%9Flamak",
#     "tweet_volume": null,
#     "name": "#BazenA\u011flamak",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%8C%E4%BD%9C%E3%82%8A%E3%81%9D%E3%81%86%E3%81%AA%E3%82%B8%E3%83%96%E3%83%AA%E4%BD%9C%E5%93%81%E3%81%AE%E3%82%BF%E3%82%A4%E3%83%88%E3%83%AB",
#     "query": "%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%8C%E4%BD%9C%E3%82%8A%E3%81%9D%E3%81%86%E3%81%AA%E3%82%B8%E3%83%96%E3%83%AA%E4%BD%9C%E5%93%81%E3%81%AE%E3%82%BF%E3%82%A4%E3%83%88%E3%83%AB",
#     "tweet_volume": 18682,
#     "name": "#\u3042\u306a\u305f\u304c\u4f5c\u308a\u305d\u3046\u306a\u30b8\u30d6\u30ea\u4f5c\u54c1\u306e\u30bf\u30a4\u30c8\u30eb",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23RIPHarmonizerSophia",
#     "query": "%23RIPHarmonizerSophia",
#     "tweet_volume": null,
#     "name": "#RIPHarmonizerSophia",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-01-16T18:25:59Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]

# %% [markdown]
# <font color='purple'><b>Question 1-2:</b></font> what are the names of the fields for each element (object) in the “trends” list and what do these fields represent?

# %% [markdown]
# <font color='purple'><b>Write down your answer for Question 1-2 in this cell:</b></font>
#
# There are five fields for each element in the "trends" list:
#
# 1. url - the search url of what topic is specifically trending.
# 2. query - the individual trending item that is being queried.
# 3. tweet_volume - the number of tweets with that specific term.
# 4. name - the term that is trending.
# 5. promoted_content - whether the specified term is flagged as promoted content.

# %% [markdown]
# <p>As you can see <q>trends</q> field contains a list of trending terms for the world. You can also find the Twitter trends in US:
# <blockquote><p>```json.dumps()``` converts a Python object ```world_trends``` into a string containing its JSON-formatted representation. The keyword ```indent = 1``` forces formatting into multiple lines with indentation of 1 for sub-object fields (without this keyword, the output will not be broken into multiple lines).</p>
# <p>Try ```indent = 0```</p>
# </blockquote>

# %%
### Code Block 1-4-a ###

try:
    WORLD_WOE_ID = 1
    world_trends = twitter_trends(twitter_api, WORLD_WOE_ID)
    print json.dumps(world_trends, indent=0)
except urllib2.URLError, e:
    print "Error", e
    #URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>
    #This error may happen if you do not have a consistent internet connection.
# Out:
# [
# {
# "created_at": "2016-01-15T16:47:53Z",
# "trends": [
# {
# "url": "http://twitter.com/search?q=%E3%83%90%E3%83%AB%E3%82%B9",
# "query": "%E3%83%90%E3%83%AB%E3%82%B9",
# "tweet_volume": 1831831,
# "name": "\u30d0\u30eb\u30b9",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%239YearsOfKidrauhl",
# "query": "%239YearsOfKidrauhl",
# "tweet_volume": 270360,
# "name": "#9YearsOfKidrauhl",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23HoyTengoGanasDe",
# "query": "%23HoyTengoGanasDe",
# "tweet_volume": null,
# "name": "#HoyTengoGanasDe",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D8%B3%D9%8A%D9%86%D8%A7%D9%8A%D9%88%D9%83%D9%8A",
# "query": "%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D8%B3%D9%8A%D9%86%D8%A7%D9%8A%D9%88%D9%83%D9%8A",
# "tweet_volume": 20179,
# "name": "#\u0627\u0644\u0647\u0644\u0627\u0644_\u0633\u064a\u0646\u0627\u064a\u0648\u0643\u064a",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23BuenViernes",
# "query": "%23BuenViernes",
# "tweet_volume": 26787,
# "name": "#BuenViernes",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%232YearsWithGOT7",
# "query": "%232YearsWithGOT7",
# "tweet_volume": 228652,
# "name": "#2YearsWithGOT7",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%E3%83%A0%E3%82%B9%E3%82%AB",
# "query": "%E3%83%A0%E3%82%B9%E3%82%AB",
# "tweet_volume": 353938,
# "name": "\u30e0\u30b9\u30ab",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%22Humberto+Moreira%22",
# "query": "%22Humberto+Moreira%22",
# "tweet_volume": null,
# "name": "Humberto Moreira",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%EC%8B%A0%EC%98%81%EB%B3%B5",
# "query": "%EC%8B%A0%EC%98%81%EB%B3%B5",
# "tweet_volume": 11230,
# "name": "\uc2e0\uc601\ubcf5",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%22Grizzly+Adams%22",
# "query": "%22Grizzly+Adams%22",
# "tweet_volume": null,
# "name": "Grizzly Adams",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%E3%83%89%E3%83%BC%E3%83%A9",
# "query": "%E3%83%89%E3%83%BC%E3%83%A9",
# "tweet_volume": 80621,
# "name": "\u30c9\u30fc\u30e9",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%EB%B0%95%EC%A7%84%EC%98%81",
# "query": "%EB%B0%95%EC%A7%84%EC%98%81",
# "tweet_volume": null,
# "name": "\ubc15\uc9c4\uc601",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%22F%C3%A9lix+Cuevas%22",
# "query": "%22F%C3%A9lix+Cuevas%22",
# "tweet_volume": 11021,
# "name": "F\u00e9lix Cuevas",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=UnidosPorLuphia",
# "query": "UnidosPorLuphia",
# "tweet_volume": null,
# "name": "UnidosPorLuphia",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=Boudou",
# "query": "Boudou",
# "tweet_volume": 16766,
# "name": "Boudou",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%E3%82%BB%E3%83%B3%E3%82%BF%E3%83%BC%E8%A9%A6%E9%A8%93",
# "query": "%E3%82%BB%E3%83%B3%E3%82%BF%E3%83%BC%E8%A9%A6%E9%A8%93",
# "tweet_volume": 199674,
# "name": "\u30bb\u30f3\u30bf\u30fc\u8a66\u9a13",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%22%D9%8A%D9%88%D8%B3%D9%81+%D8%A7%D9%84%D8%B3%D8%A7%D9%84%D9%85%22",
# "query": "%22%D9%8A%D9%88%D8%B3%D9%81+%D8%A7%D9%84%D8%B3%D8%A7%D9%84%D9%85%22",
# "tweet_volume": null,
# "name": "\u064a\u0648\u0633\u0641 \u0627\u0644\u0633\u0627\u0644\u0645",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%22Mos+Def%22",
# "query": "%22Mos+Def%22",
# "tweet_volume": null,
# "name": "Mos Def",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=M%E3%82%B9%E3%83%86",
# "query": "M%E3%82%B9%E3%83%86",
# "tweet_volume": 160508,
# "name": "M\u30b9\u30c6",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%22Ariana+Army%22",
# "query": "%22Ariana+Army%22",
# "tweet_volume": 15177,
# "name": "Ariana Army",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23ALDUB6thMonthsary",
# "query": "%23ALDUB6thMonthsary",
# "tweet_volume": 382679,
# "name": "#ALDUB6thMonthsary",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23BrazilLovesDinah",
# "query": "%23BrazilLovesDinah",
# "tweet_volume": null,
# "name": "#BrazilLovesDinah",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23happyBOOday",
# "query": "%23happyBOOday",
# "tweet_volume": 39512,
# "name": "#happyBOOday",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23MensajeAlPueblo",
# "query": "%23MensajeAlPueblo",
# "tweet_volume": 28339,
# "name": "#MensajeAlPueblo",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8363",
# "query": "%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8363",
# "tweet_volume": null,
# "name": "#\u0632\u062f_\u0631\u0635\u064a\u062f\u064363",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23PraMeConquistar",
# "query": "%23PraMeConquistar",
# "tweet_volume": 11898,
# "name": "#PraMeConquistar",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%234anosDeT3ddy",
# "query": "%234anosDeT3ddy",
# "tweet_volume": null,
# "name": "#4anosDeT3ddy",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23Kad%C4%B1nlarNe%C4%B0sterBiliyormusun",
# "query": "%23Kad%C4%B1nlarNe%C4%B0sterBiliyormusun",
# "tweet_volume": 12173,
# "name": "#Kad\u0131nlarNe\u0130sterBiliyormusun",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23SextaFavQSdvDetremura",
# "query": "%23SextaFavQSdvDetremura",
# "tweet_volume": 34784,
# "name": "#SextaFavQSdvDetremura",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23FridayFeeling",
# "query": "%23FridayFeeling",
# "tweet_volume": 30726,
# "name": "#FridayFeeling",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23%D8%B3%D8%A7%D8%B9%D9%87_%D8%A7%D8%B3%D8%AA%D8%AC%D8%A7%D8%A8%D9%87",
# "query": "%23%D8%B3%D8%A7%D8%B9%D9%87_%D8%A7%D8%B3%D8%AA%D8%AC%D8%A7%D8%A8%D9%87",
# "tweet_volume": 43090,
# "name": "#\u0633\u0627\u0639\u0647_\u0627\u0633\u062a\u062c\u0627\u0628\u0647",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23spacewalk",
# "query": "%23spacewalk",
# "tweet_volume": 36261,
# "name": "#spacewalk",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23PrimeraQuincenaDelA%C3%B1oYYo",
# "query": "%23PrimeraQuincenaDelA%C3%B1oYYo",
# "tweet_volume": null,
# "name": "#PrimeraQuincenaDelA\u00f1oYYo",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23TheFilmfareLYF",
# "query": "%23TheFilmfareLYF",
# "tweet_volume": null,
# "name": "#TheFilmfareLYF",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23bitince",
# "query": "%23bitince",
# "tweet_volume": 18010,
# "name": "#bitince",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23NewYorkValues",
# "query": "%23NewYorkValues",
# "tweet_volume": 31649,
# "name": "#NewYorkValues",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23SonraNeMiOldu",
# "query": "%23SonraNeMiOldu",
# "tweet_volume": null,
# "name": "#SonraNeMiOldu",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23teog",
# "query": "%23teog",
# "tweet_volume": null,
# "name": "#teog",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23NationalHatDay",
# "query": "%23NationalHatDay",
# "tweet_volume": null,
# "name": "#NationalHatDay",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23%D0%98%D0%BC%D0%B1%D0%B8%D1%86%D0%B8%D0%BB%D0%A4%D0%BE%D0%BB%D0%BB%D0%BE%D0%B2%D0%B8%D1%82%D0%9A%D1%80%D0%B5%D1%82%D0%B8%D0%BD%D0%B0",
# "query": "%23%D0%98%D0%BC%D0%B1%D0%B8%D1%86%D0%B8%D0%BB%D0%A4%D0%BE%D0%BB%D0%BB%D0%BE%D0%B2%D0%B8%D1%82%D0%9A%D1%80%D0%B5%D1%82%D0%B8%D0%BD%D0%B0",
# "tweet_volume": null,
# "name": "#\u0418\u043c\u0431\u0438\u0446\u0438\u043b\u0424\u043e\u043b\u043b\u043e\u0432\u0438\u0442\u041a\u0440\u0435\u0442\u0438\u043d\u0430",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23WMYBTo1Billion",
# "query": "%23WMYBTo1Billion",
# "tweet_volume": null,
# "name": "#WMYBTo1Billion",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23UGDebate16",
# "query": "%23UGDebate16",
# "tweet_volume": 18412,
# "name": "#UGDebate16",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23ColombiaDiceNo",
# "query": "%23ColombiaDiceNo",
# "tweet_volume": 11142,
# "name": "#ColombiaDiceNo",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23%EC%A0%9C_%EA%B7%B8%EB%A6%BC%EC%B2%B4%EB%8A%94_%EA%B3%B5_%EA%B0%99%EB%82%98%EC%9A%94_%EC%88%98_%EA%B0%99%EB%82%98%EC%9A%94",
# "query": "%23%EC%A0%9C_%EA%B7%B8%EB%A6%BC%EC%B2%B4%EB%8A%94_%EA%B3%B5_%EA%B0%99%EB%82%98%EC%9A%94_%EC%88%98_%EA%B0%99%EB%82%98%EC%9A%94",
# "tweet_volume": null,
# "name": "#\uc81c_\uadf8\ub9bc\uccb4\ub294_\uacf5_\uac19\ub098\uc694_\uc218_\uac19\ub098\uc694",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23RT%ED%95%9C_%ED%8A%B8%EC%B9%9C%EC%9D%98_%EB%B3%B8%EB%AA%85%EC%9D%84_%EC%98%88%EC%83%81%ED%95%B4%EB%B3%B8%EB%8B%A4",
# "query": "%23RT%ED%95%9C_%ED%8A%B8%EC%B9%9C%EC%9D%98_%EB%B3%B8%EB%AA%85%EC%9D%84_%EC%98%88%EC%83%81%ED%95%B4%EB%B3%B8%EB%8B%A4",
# "tweet_volume": null,
# "name": "#RT\ud55c_\ud2b8\uce5c\uc758_\ubcf8\uba85\uc744_\uc608\uc0c1\ud574\ubcf8\ub2e4",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23DukungOngenBebas",
# "query": "%23DukungOngenBebas",
# "tweet_volume": 19488,
# "name": "#DukungOngenBebas",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23NWSLDraft",
# "query": "%23NWSLDraft",
# "tweet_volume": null,
# "name": "#NWSLDraft",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23Vicdan%C4%B1OlanSusmazEdiBESE",
# "query": "%23Vicdan%C4%B1OlanSusmazEdiBESE",
# "tweet_volume": null,
# "name": "#Vicdan\u0131OlanSusmazEdiBESE",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23UneSyllabeQuiChangeTout",
# "query": "%23UneSyllabeQuiChangeTout",
# "tweet_volume": null,
# "name": "#UneSyllabeQuiChangeTout",
# "promoted_content": null
# },
# {
# "url": "http://twitter.com/search?q=%23envipdiosos",
# "query": "%23envipdiosos",
# "tweet_volume": null,
# "name": "#envipdiosos",
# "promoted_content": null
# }
# ],
# "as_of": "2016-01-15T16:55:53Z",
# "locations": [
# {
# "woeid": 1,
# "name": "Worldwide"
# }
# ]
# }
# ]

# %%
### Code Block 1-5 ###

try:
    US_WOE_ID = 23424977
    us_trends = twitter_trends(twitter_api, US_WOE_ID)
    print json.dumps(us_trends, indent=1)
except urllib2.URLError, e:
    print "Error", e
    #URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>
    #This error may happen if you do not have a consistent internet connection.
# Out:
# [
#  {
#   "created_at": "2016-01-15T16:47:53Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23NewYorkValues",
#     "query": "%23NewYorkValues",
#     "tweet_volume": 31649,
#     "name": "#NewYorkValues",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Grizzly+Adams%22",
#     "query": "%22Grizzly+Adams%22",
#     "tweet_volume": null,
#     "name": "Grizzly Adams",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%239YearsOfKidrauhl",
#     "query": "%239YearsOfKidrauhl",
#     "tweet_volume": 270360,
#     "name": "#9YearsOfKidrauhl",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NationalHatDay",
#     "query": "%23NationalHatDay",
#     "tweet_volume": null,
#     "name": "#NationalHatDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23fridayreads",
#     "query": "%23fridayreads",
#     "tweet_volume": null,
#     "name": "#fridayreads",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NWSLDraft",
#     "query": "%23NWSLDraft",
#     "tweet_volume": null,
#     "name": "#NWSLDraft",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Lindsey+Graham%22",
#     "query": "%22Lindsey+Graham%22",
#     "tweet_volume": 11585,
#     "name": "Lindsey Graham",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Cloverfield",
#     "query": "Cloverfield",
#     "tweet_volume": 45979,
#     "name": "Cloverfield",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jim+Caldwell%22",
#     "query": "%22Jim+Caldwell%22",
#     "tweet_volume": null,
#     "name": "Jim Caldwell",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Cris+Carter%22",
#     "query": "%22Cris+Carter%22",
#     "tweet_volume": null,
#     "name": "Cris Carter",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Mos+Def%22",
#     "query": "%22Mos+Def%22",
#     "tweet_volume": null,
#     "name": "Mos Def",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Martin+Luther+King%22",
#     "query": "%22Martin+Luther+King%22",
#     "tweet_volume": 37339,
#     "name": "Martin Luther King",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ben+McAdoo%22",
#     "query": "%22Ben+McAdoo%22",
#     "tweet_volume": 17598,
#     "name": "Ben McAdoo",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dr.+King%22",
#     "query": "%22Dr.+King%22",
#     "tweet_volume": null,
#     "name": "Dr. King",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Happy+Founders%22",
#     "query": "%22Happy+Founders%22",
#     "tweet_volume": 10606,
#     "name": "Happy Founders",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Clarion",
#     "query": "Clarion",
#     "tweet_volume": null,
#     "name": "Clarion",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Matt+Barnes%22",
#     "query": "%22Matt+Barnes%22",
#     "tweet_volume": null,
#     "name": "Matt Barnes",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Oahu",
#     "query": "Oahu",
#     "tweet_volume": null,
#     "name": "Oahu",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Murder+Kroger%22",
#     "query": "%22Murder+Kroger%22",
#     "tweet_volume": null,
#     "name": "Murder Kroger",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Chris+Tabor%22",
#     "query": "%22Chris+Tabor%22",
#     "tweet_volume": null,
#     "name": "Chris Tabor",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Tornado+Watch%22",
#     "query": "%22Tornado+Watch%22",
#     "tweet_volume": null,
#     "name": "Tornado Watch",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Happy+Birthday+MLK%22",
#     "query": "%22Happy+Birthday+MLK%22",
#     "tweet_volume": null,
#     "name": "Happy Birthday MLK",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22The+Division%22",
#     "query": "%22The+Division%22",
#     "tweet_volume": 17101,
#     "name": "The Division",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Urbandale",
#     "query": "Urbandale",
#     "tweet_volume": null,
#     "name": "Urbandale",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Washington+Spirit%22",
#     "query": "%22Washington+Spirit%22",
#     "tweet_volume": null,
#     "name": "Washington Spirit",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22WR+Antonio+Brown%22",
#     "query": "%22WR+Antonio+Brown%22",
#     "tweet_volume": null,
#     "name": "WR Antonio Brown",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Carson+Pickett%22",
#     "query": "%22Carson+Pickett%22",
#     "tweet_volume": null,
#     "name": "Carson Pickett",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Humberto+Moreira%22",
#     "query": "%22Humberto+Moreira%22",
#     "tweet_volume": null,
#     "name": "Humberto Moreira",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Tzuyu",
#     "query": "Tzuyu",
#     "tweet_volume": 90844,
#     "name": "Tzuyu",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FlashbackFriday",
#     "query": "%23FlashbackFriday",
#     "tweet_volume": null,
#     "name": "#FlashbackFriday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23spacewalk",
#     "query": "%23spacewalk",
#     "tweet_volume": 36261,
#     "name": "#spacewalk",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Walmart",
#     "query": "%23Walmart",
#     "tweet_volume": null,
#     "name": "#Walmart",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CentralPerkSongs",
#     "query": "%23CentralPerkSongs",
#     "tweet_volume": null,
#     "name": "#CentralPerkSongs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EulogyDosAndDonts",
#     "query": "%23EulogyDosAndDonts",
#     "tweet_volume": null,
#     "name": "#EulogyDosAndDonts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%232YearsWithGOT7",
#     "query": "%232YearsWithGOT7",
#     "tweet_volume": 228652,
#     "name": "#2YearsWithGOT7",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23artofchange",
#     "query": "%23artofchange",
#     "tweet_volume": null,
#     "name": "#artofchange",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MLKDay",
#     "query": "%23MLKDay",
#     "tweet_volume": null,
#     "name": "#MLKDay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BlueFriday",
#     "query": "%23BlueFriday",
#     "tweet_volume": null,
#     "name": "#BlueFriday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BuenViernes",
#     "query": "%23BuenViernes",
#     "tweet_volume": 26787,
#     "name": "#BuenViernes",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23replacetroyelyricswithikea",
#     "query": "%23replacetroyelyricswithikea",
#     "tweet_volume": null,
#     "name": "#replacetroyelyricswithikea",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MakeGEpay",
#     "query": "%23MakeGEpay",
#     "tweet_volume": null,
#     "name": "#MakeGEpay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PreventVE",
#     "query": "%23PreventVE",
#     "tweet_volume": null,
#     "name": "#PreventVE",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SurvOnc16",
#     "query": "%23SurvOnc16",
#     "tweet_volume": null,
#     "name": "#SurvOnc16",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ALDUB6thMonthsary",
#     "query": "%23ALDUB6thMonthsary",
#     "tweet_volume": 382679,
#     "name": "#ALDUB6thMonthsary",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23countrycares",
#     "query": "%23countrycares",
#     "tweet_volume": null,
#     "name": "#countrycares",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OrangeFriday",
#     "query": "%23OrangeFriday",
#     "tweet_volume": null,
#     "name": "#OrangeFriday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MuseumsAreUs",
#     "query": "%23MuseumsAreUs",
#     "tweet_volume": null,
#     "name": "#MuseumsAreUs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MensajeAlPueblo",
#     "query": "%23MensajeAlPueblo",
#     "tweet_volume": 28339,
#     "name": "#MensajeAlPueblo",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LeahStrong",
#     "query": "%23LeahStrong",
#     "tweet_volume": null,
#     "name": "#LeahStrong",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NewMusicFriday",
#     "query": "%23NewMusicFriday",
#     "tweet_volume": null,
#     "name": "#NewMusicFriday",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-01-15T16:56:21Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %% [markdown]
# <font color='purple'><b>Question 1-3:</b></font> Find the Twitter trends in Canada and Toronto.
# <p>Hint<font color='red'>\*</font>: ```US_WOE_ID``` and ```us_trends``` are used to find the Twitter trends in <font color='blue'>US</font>. Use ```CA_WOE_ID``` and ```TRT_WOE_ID``` in place of ```US_WOE_ID```. Use ```ca_trends``` and ```trt_trends``` in place of ```us_trends```. ```WOE_IDs``` for Canada and Toronto can be found at <a href = "http://woeid.rosselliot.co.nz">http://woeid.rosselliot.co.nz</a>.</p>
#
# The modified code can be found below:

# %%
### Write down your answer for Question 1-3 in this cell ###
### Your answer is python code that is similar to Code 1-5 with appropriate changes ###
### Code Block 1-5-a ###

try:
    TOR_WOE_ID = 4118
    tr_trends = twitter_trends(twitter_api, TOR_WOE_ID)
    print json.dumps(tr_trends, indent=1)
except urllib2.URLError, e:
    print "Error", e
    
try:
    CN_WOE_ID = 23424775
    ca_trends = twitter_trends(twitter_api, CN_WOE_ID)
    print json.dumps(ca_trends, indent=1)
except urllib2.URLError, e:
    print "Error", e
# Out:
# [
#  {
#   "created_at": "2016-01-16T18:21:24Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23FilmFreeway",
#     "query": "%23FilmFreeway",
#     "tweet_volume": null,
#     "name": "#FilmFreeway",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Canada+Is+Suddenly%22",
#     "query": "%22Canada+Is+Suddenly%22",
#     "tweet_volume": null,
#     "name": "Canada Is Suddenly",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ProjectWinterSurvival",
#     "query": "%23ProjectWinterSurvival",
#     "tweet_volume": null,
#     "name": "#ProjectWinterSurvival",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PrideTO",
#     "query": "%23PrideTO",
#     "tweet_volume": null,
#     "name": "#PrideTO",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22David+MacNaughton%22",
#     "query": "%22David+MacNaughton%22",
#     "tweet_volume": null,
#     "name": "David MacNaughton",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Chelsea",
#     "query": "Chelsea",
#     "tweet_volume": 295282,
#     "name": "Chelsea",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OTTHAC16",
#     "query": "%23OTTHAC16",
#     "tweet_volume": null,
#     "name": "#OTTHAC16",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WhitbyOshawa",
#     "query": "%23WhitbyOshawa",
#     "tweet_volume": null,
#     "name": "#WhitbyOshawa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22John+Terry%22",
#     "query": "%22John+Terry%22",
#     "tweet_volume": 60364,
#     "name": "John Terry",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Everton",
#     "query": "Everton",
#     "tweet_volume": 177733,
#     "name": "Everton",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ian+Kennedy%22",
#     "query": "%22Ian+Kennedy%22",
#     "tweet_volume": null,
#     "name": "Ian Kennedy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Aaliyah",
#     "query": "Aaliyah",
#     "tweet_volume": 68386,
#     "name": "Aaliyah",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Costa",
#     "query": "Costa",
#     "tweet_volume": 115032,
#     "name": "Costa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Orioles",
#     "query": "Orioles",
#     "tweet_volume": 20960,
#     "name": "Orioles",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Washington+Post%22",
#     "query": "%22Washington+Post%22",
#     "tweet_volume": 30350,
#     "name": "Washington Post",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Hagelin",
#     "query": "Hagelin",
#     "tweet_volume": 11016,
#     "name": "Hagelin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jonjo+Shelvey%22",
#     "query": "%22Jonjo+Shelvey%22",
#     "tweet_volume": null,
#     "name": "Jonjo Shelvey",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22U.S.+and+UN%22",
#     "query": "%22U.S.+and+UN%22",
#     "tweet_volume": null,
#     "name": "U.S. and UN",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22John+Scott%22",
#     "query": "%22John+Scott%22",
#     "tweet_volume": 38806,
#     "name": "John Scott",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ren%C3%A9+Ang%C3%A9lil%22",
#     "query": "%22Ren%C3%A9+Ang%C3%A9lil%22",
#     "tweet_volume": 17630,
#     "name": "Ren\u00e9 Ang\u00e9lil",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Tinordi",
#     "query": "Tinordi",
#     "tweet_volume": 12649,
#     "name": "Tinordi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Alan+Rickman%22",
#     "query": "%22Alan+Rickman%22",
#     "tweet_volume": 200942,
#     "name": "Alan Rickman",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Patrick+Kane%22",
#     "query": "%22Patrick+Kane%22",
#     "tweet_volume": null,
#     "name": "Patrick Kane",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Grizzly+Adams%22",
#     "query": "%22Grizzly+Adams%22",
#     "tweet_volume": 21577,
#     "name": "Grizzly Adams",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pacific+Centre%22",
#     "query": "%22Pacific+Centre%22",
#     "tweet_volume": null,
#     "name": "Pacific Centre",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Victor+Bartley%22",
#     "query": "%22Victor+Bartley%22",
#     "tweet_volume": null,
#     "name": "Victor Bartley",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ImABadCanadianBecause",
#     "query": "%23ImABadCanadianBecause",
#     "tweet_volume": null,
#     "name": "#ImABadCanadianBecause",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TEDxLangleyED",
#     "query": "%23TEDxLangleyED",
#     "tweet_volume": null,
#     "name": "#TEDxLangleyED",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CFCvEFC",
#     "query": "%23CFCvEFC",
#     "tweet_volume": null,
#     "name": "#CFCvEFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AWNChat",
#     "query": "%23AWNChat",
#     "tweet_volume": null,
#     "name": "#AWNChat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JasonRezaian",
#     "query": "%23JasonRezaian",
#     "tweet_volume": null,
#     "name": "#JasonRezaian",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IfIDidntKnowBetterIdThink",
#     "query": "%23IfIDidntKnowBetterIdThink",
#     "tweet_volume": null,
#     "name": "#IfIDidntKnowBetterIdThink",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheySayItsImpossibleBut",
#     "query": "%23TheySayItsImpossibleBut",
#     "tweet_volume": null,
#     "name": "#TheySayItsImpossibleBut",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Brunch",
#     "query": "%23Brunch",
#     "tweet_volume": null,
#     "name": "#Brunch",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IranDeal",
#     "query": "%23IranDeal",
#     "tweet_volume": null,
#     "name": "#IranDeal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ldnbudget",
#     "query": "%23ldnbudget",
#     "tweet_volume": null,
#     "name": "#ldnbudget",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23screenshotsaturday",
#     "query": "%23screenshotsaturday",
#     "tweet_volume": null,
#     "name": "#screenshotsaturday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PatsNation",
#     "query": "%23PatsNation",
#     "tweet_volume": null,
#     "name": "#PatsNation",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MCFC",
#     "query": "%23MCFC",
#     "tweet_volume": 26509,
#     "name": "#MCFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23edcampbarrie",
#     "query": "%23edcampbarrie",
#     "tweet_volume": null,
#     "name": "#edcampbarrie",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CHAN2016",
#     "query": "%23CHAN2016",
#     "tweet_volume": null,
#     "name": "#CHAN2016",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23esktransformationweekend",
#     "query": "%23esktransformationweekend",
#     "tweet_volume": null,
#     "name": "#esktransformationweekend",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Caturday",
#     "query": "%23Caturday",
#     "tweet_volume": null,
#     "name": "#Caturday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MyJasper",
#     "query": "%23MyJasper",
#     "tweet_volume": null,
#     "name": "#MyJasper",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MakeMeThinkIn5Words",
#     "query": "%23MakeMeThinkIn5Words",
#     "tweet_volume": 50693,
#     "name": "#MakeMeThinkIn5Words",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ALDUB6thMonthsary",
#     "query": "%23ALDUB6thMonthsary",
#     "tweet_volume": 5398198,
#     "name": "#ALDUB6thMonthsary",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%239YearsOfKidrauhl",
#     "query": "%239YearsOfKidrauhl",
#     "tweet_volume": 171621,
#     "name": "#9YearsOfKidrauhl",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BurkinaFaso",
#     "query": "%23BurkinaFaso",
#     "tweet_volume": 40654,
#     "name": "#BurkinaFaso",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NewYorkValues",
#     "query": "%23NewYorkValues",
#     "tweet_volume": 55622,
#     "name": "#NewYorkValues",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BlueBloods",
#     "query": "%23BlueBloods",
#     "tweet_volume": null,
#     "name": "#BlueBloods",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-01-16T18:26:20Z",
#   "locations": [
#    {
#     "woeid": 4118,
#     "name": "Toronto"
#    }
#   ]
#  }
# ]
# [
#  {
#   "created_at": "2016-01-16T18:21:23Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23TEDxLangleyED",
#     "query": "%23TEDxLangleyED",
#     "tweet_volume": null,
#     "name": "#TEDxLangleyED",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22John+Terry%22",
#     "query": "%22John+Terry%22",
#     "tweet_volume": 60364,
#     "name": "John Terry",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Chelsea",
#     "query": "Chelsea",
#     "tweet_volume": 295282,
#     "name": "Chelsea",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ProjectWinterSurvival",
#     "query": "%23ProjectWinterSurvival",
#     "tweet_volume": null,
#     "name": "#ProjectWinterSurvival",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FilmFreeway",
#     "query": "%23FilmFreeway",
#     "tweet_volume": null,
#     "name": "#FilmFreeway",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Everton",
#     "query": "Everton",
#     "tweet_volume": 177733,
#     "name": "Everton",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Canada+Is+Suddenly%22",
#     "query": "%22Canada+Is+Suddenly%22",
#     "tweet_volume": null,
#     "name": "Canada Is Suddenly",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CFCvEFC",
#     "query": "%23CFCvEFC",
#     "tweet_volume": null,
#     "name": "#CFCvEFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AWNChat",
#     "query": "%23AWNChat",
#     "tweet_volume": null,
#     "name": "#AWNChat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ian+Kennedy%22",
#     "query": "%22Ian+Kennedy%22",
#     "tweet_volume": null,
#     "name": "Ian Kennedy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22David+MacNaughton%22",
#     "query": "%22David+MacNaughton%22",
#     "tweet_volume": null,
#     "name": "David MacNaughton",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Aaliyah",
#     "query": "Aaliyah",
#     "tweet_volume": 68386,
#     "name": "Aaliyah",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Costa",
#     "query": "Costa",
#     "tweet_volume": 115032,
#     "name": "Costa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Orioles",
#     "query": "Orioles",
#     "tweet_volume": 20960,
#     "name": "Orioles",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Washington+Post%22",
#     "query": "%22Washington+Post%22",
#     "tweet_volume": 30350,
#     "name": "Washington Post",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Hagelin",
#     "query": "Hagelin",
#     "tweet_volume": 11016,
#     "name": "Hagelin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jonjo+Shelvey%22",
#     "query": "%22Jonjo+Shelvey%22",
#     "tweet_volume": null,
#     "name": "Jonjo Shelvey",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22U.S.+and+UN%22",
#     "query": "%22U.S.+and+UN%22",
#     "tweet_volume": null,
#     "name": "U.S. and UN",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22John+Scott%22",
#     "query": "%22John+Scott%22",
#     "tweet_volume": 38806,
#     "name": "John Scott",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ren%C3%A9+Ang%C3%A9lil%22",
#     "query": "%22Ren%C3%A9+Ang%C3%A9lil%22",
#     "tweet_volume": 17630,
#     "name": "Ren\u00e9 Ang\u00e9lil",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Tinordi",
#     "query": "Tinordi",
#     "tweet_volume": 12649,
#     "name": "Tinordi",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Alan+Rickman%22",
#     "query": "%22Alan+Rickman%22",
#     "tweet_volume": 200942,
#     "name": "Alan Rickman",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Patrick+Kane%22",
#     "query": "%22Patrick+Kane%22",
#     "tweet_volume": null,
#     "name": "Patrick Kane",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Grizzly+Adams%22",
#     "query": "%22Grizzly+Adams%22",
#     "tweet_volume": 21577,
#     "name": "Grizzly Adams",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Pacific+Centre%22",
#     "query": "%22Pacific+Centre%22",
#     "tweet_volume": null,
#     "name": "Pacific Centre",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Victor+Bartley%22",
#     "query": "%22Victor+Bartley%22",
#     "tweet_volume": null,
#     "name": "Victor Bartley",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Ouagadougou",
#     "query": "Ouagadougou",
#     "tweet_volume": 93450,
#     "name": "Ouagadougou",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23JasonRezaian",
#     "query": "%23JasonRezaian",
#     "tweet_volume": null,
#     "name": "#JasonRezaian",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IfIDidntKnowBetterIdThink",
#     "query": "%23IfIDidntKnowBetterIdThink",
#     "tweet_volume": null,
#     "name": "#IfIDidntKnowBetterIdThink",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23OTTHAC16",
#     "query": "%23OTTHAC16",
#     "tweet_volume": null,
#     "name": "#OTTHAC16",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheySayItsImpossibleBut",
#     "query": "%23TheySayItsImpossibleBut",
#     "tweet_volume": null,
#     "name": "#TheySayItsImpossibleBut",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PrideTO",
#     "query": "%23PrideTO",
#     "tweet_volume": null,
#     "name": "#PrideTO",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Brunch",
#     "query": "%23Brunch",
#     "tweet_volume": null,
#     "name": "#Brunch",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IranDeal",
#     "query": "%23IranDeal",
#     "tweet_volume": null,
#     "name": "#IranDeal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ldnbudget",
#     "query": "%23ldnbudget",
#     "tweet_volume": null,
#     "name": "#ldnbudget",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23screenshotsaturday",
#     "query": "%23screenshotsaturday",
#     "tweet_volume": null,
#     "name": "#screenshotsaturday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PatsNation",
#     "query": "%23PatsNation",
#     "tweet_volume": null,
#     "name": "#PatsNation",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MCFC",
#     "query": "%23MCFC",
#     "tweet_volume": 26509,
#     "name": "#MCFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23edcampbarrie",
#     "query": "%23edcampbarrie",
#     "tweet_volume": null,
#     "name": "#edcampbarrie",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CHAN2016",
#     "query": "%23CHAN2016",
#     "tweet_volume": null,
#     "name": "#CHAN2016",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23esktransformationweekend",
#     "query": "%23esktransformationweekend",
#     "tweet_volume": null,
#     "name": "#esktransformationweekend",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Caturday",
#     "query": "%23Caturday",
#     "tweet_volume": null,
#     "name": "#Caturday",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MyJasper",
#     "query": "%23MyJasper",
#     "tweet_volume": null,
#     "name": "#MyJasper",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ImABadCanadianBecause",
#     "query": "%23ImABadCanadianBecause",
#     "tweet_volume": null,
#     "name": "#ImABadCanadianBecause",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MakeMeThinkIn5Words",
#     "query": "%23MakeMeThinkIn5Words",
#     "tweet_volume": 50693,
#     "name": "#MakeMeThinkIn5Words",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ALDUB6thMonthsary",
#     "query": "%23ALDUB6thMonthsary",
#     "tweet_volume": 5398198,
#     "name": "#ALDUB6thMonthsary",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%239YearsOfKidrauhl",
#     "query": "%239YearsOfKidrauhl",
#     "tweet_volume": 171621,
#     "name": "#9YearsOfKidrauhl",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BurkinaFaso",
#     "query": "%23BurkinaFaso",
#     "tweet_volume": 40654,
#     "name": "#BurkinaFaso",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NewYorkValues",
#     "query": "%23NewYorkValues",
#     "tweet_volume": 55622,
#     "name": "#NewYorkValues",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BlueBloods",
#     "query": "%23BlueBloods",
#     "tweet_volume": null,
#     "name": "#BlueBloods",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-01-16T18:26:20Z",
#   "locations": [
#    {
#     "woeid": 23424775,
#     "name": "Canada"
#    }
#   ]
#  }
# ]

# %% [markdown]
# <p>Results can also be saved into text files as follows:</p>

# %%
### Code Block 1-6 ###

fw = open('wt.json','w')
json.dump(tr_trends,fw,indent=1)
fw.close()
fc = open('ct.json','w')
json.dump(ca_trends,fc,indent=1)
fc.close()

# %% [markdown]
# <blockquote><p>The above code opens the text files ```wt.json``` and ```ct.json``` for writing (using ```open()``` function) and calls ```json.dump()``` method to print trend results (with indentation). In the tutorial for the next lecture, we will examine how to save results in a document-based DB (MongoDB). Results can also be manipulated for analysis.</p>
# <p><font color='blue'>Check</font> your current folder for the files ```wt.json``` and ```ct.json```.<p>
# </blockquote>
#
# <p>Consider the lists of trending topics in the whole world and in Canada: </p>

# %% [markdown]
# <p>We now convert these lists into sets:</p>
#
# <blockquote><p> You have to finish <font color='purple'><b>Question 1-3</b></font> to run Code Block 1-7. Otherwise, change ```ca_trends``` to ```us_trends``` in Code Block 1-7.
# </p></blockquote>

# %%
### Code Block 1-7 ###

wn = [ t['name'] for t in world_trends[0]['trends'] ]
cn = [ t['name'] for t in ca_trends[0]['trends'] ]

w_set = set(wn)
c_set = set(cn)
common_trends = w_set.intersection(c_set)

# %% [markdown]
# <font color='purple'><b>Question 1-4:</b></font>
# <ul>
# <li>What topics do these lists include? Use print command to display wn and cn.</li>
# <li>Print to check whether there are any topics in common. What is the output of this print statement?</li>
# </ul>

# %%
## Your Code for Question 1-4 ##

print "\n".join(wn) 
print "\n".join(cn) 
print "\n".join(common_trends)
# Out:
# #زد_رصيدك64
# #PelículasQueHeVistoMilVeces
# Chelsea
# #السعوديه_كوريا_الشماليه
# #SabadoDetremuraSdv
# #TFCPSG
# Milagro Sala
# Mahrez
# Sinan Gümüş
# I LOVE ZAYN
# Jason Rezaian
# Aaliyah
# Guidetti
# HOY JUEGA BOCA
# AVRIL FEAT HARRY
# #SomosFasDeBandinhaCoreana
# #Bang100Milhões
# #FelizSabado
# #شنو_راح_يقولون_عنك_بالمستقبل
# #تصدق_بتغريده_لوالديك
# #CBLoL
# #EuPrecisoDe
# #小泉花陽生誕祭2016
# #ÇokHoşOlurdu
# #ViveLaPatria
# #MagconTourToMexico
# #PeorQueUnPeloEnLaSopa
# #LucasLuccoNoCaldeirao
# #شو_مزعلك
# #DoYourJob
# #알티당_실제성격
# #ДирекшионерыЗахватятВселенную
# #EsteFinde
# #10milyonliramolsa
# #HappyKanginDay
# #ConRobertEnBatalla
# #AtalantaInter
# #voleinaredetv
# #TheySayItsImpossibleBut
# #BerxwedanSerhildanJiyane
# #Amici15
# #JustinMeetDalelyla
# #SAvENG
# #التويتراويه_وفولورز_يناير
# #TorinoFrosinone
# #ESPGER
# #AVLLEI
# #BazenAğlamak
# #あなたが作りそうなジブリ作品のタイトル
# #RIPHarmonizerSophia
# #TEDxLangleyED
# John Terry
# Chelsea
# #ProjectWinterSurvival
# #FilmFreeway
# Everton
# Canada Is Suddenly
# #CFCvEFC
# #AWNChat
# Ian Kennedy
# David MacNaughton
# Aaliyah
# Costa
# Orioles
# Washington Post
# Hagelin
# Jonjo Shelvey
# U.S. and UN
# John Scott
# René Angélil
# Tinordi
# Alan Rickman
# Patrick Kane
# Grizzly Adams
# Pacific Centre
# Victor Bartley
# Ouagadougou
# #JasonRezaian
# #IfIDidntKnowBetterIdThink
# #OTTHAC16
# #TheySayItsImpossibleBut
# #PrideTO
# #Brunch
# #IranDeal
# #ldnbudget
# #screenshotsaturday
# #PatsNation
# #MCFC
# #edcampbarrie
# #CHAN2016
# #esktransformationweekend
# #Caturday
# #MyJasper
# #ImABadCanadianBecause
# #MakeMeThinkIn5Words
# #ALDUB6thMonthsary
# #9YearsOfKidrauhl
# #BurkinaFaso
# #NewYorkValues
# #BlueBloods
# Aaliyah
# #TheySayItsImpossibleBut
# Chelsea

# %% [markdown]
# Output
#
# #زد_رصيدك64
# #PelículasQueHeVistoMilVeces
# Chelsea
# #السعوديه_كوريا_الشماليه
# #SabadoDetremuraSdv
# #TFCPSG
# Milagro Sala
# Mahrez
# Sinan Gümüş
# I LOVE ZAYN
# Jason Rezaian
# Aaliyah
# Guidetti
# HOY JUEGA BOCA
# AVRIL FEAT HARRY
# #SomosFasDeBandinhaCoreana
# #Bang100Milhões
# #FelizSabado
# #شنو_راح_يقولون_عنك_بالمستقبل
# #تصدق_بتغريده_لوالديك
# #CBLoL
# #EuPrecisoDe
# #小泉花陽生誕祭2016
# #ÇokHoşOlurdu
# #ViveLaPatria
# #MagconTourToMexico
# #PeorQueUnPeloEnLaSopa
# #LucasLuccoNoCaldeirao
# #شو_مزعلك
# #DoYourJob
# #알티당_실제성격
# #ДирекшионерыЗахватятВселенную
# #EsteFinde
# #10milyonliramolsa
# #HappyKanginDay
# #ConRobertEnBatalla
# #AtalantaInter
# #voleinaredetv
# #TheySayItsImpossibleBut
# #BerxwedanSerhildanJiyane
# #Amici15
# #JustinMeetDalelyla
# #SAvENG
# #التويتراويه_وفولورز_يناير
# #TorinoFrosinone
# #ESPGER
# #AVLLEI
# #BazenAğlamak
# #あなたが作りそうなジブリ作品のタイトル
# #RIPHarmonizerSophia
# #TEDxLangleyED
# John Terry
# Chelsea
# #ProjectWinterSurvival
# #FilmFreeway
# Everton
# Canada Is Suddenly
# #CFCvEFC
# #AWNChat
# Ian Kennedy
# David MacNaughton
# Aaliyah
# Costa
# Orioles
# Washington Post
# Hagelin
# Jonjo Shelvey
# U.S. and UN
# John Scott
# René Angélil
# Tinordi
# Alan Rickman
# Patrick Kane
# Grizzly Adams
# Pacific Centre
# Victor Bartley
# Ouagadougou
# #JasonRezaian
# #IfIDidntKnowBetterIdThink
# #OTTHAC16
# #TheySayItsImpossibleBut
# #PrideTO
# #Brunch
# #IranDeal
# #ldnbudget
# #screenshotsaturday
# #PatsNation
# #MCFC
# #edcampbarrie
# #CHAN2016
# #esktransformationweekend
# #Caturday
# #MyJasper
# #ImABadCanadianBecause
# #MakeMeThinkIn5Words
# #ALDUB6thMonthsary
# #9YearsOfKidrauhl
# #BurkinaFaso
# #NewYorkValues
# #BlueBloods
# Aaliyah
# #TheySayItsImpossibleBut
# Chelsea

# %% [markdown]
# To conclude this part, we briefly examine Twitter’s Search API. This aspect gets complicated, because Twitter limits the rate at which data can be obtained (see <a href = "https://dev.twitter.com/docs/rate-limiting/1.1">https://dev.twitter.com/docs/rate-limiting/1.1</a>), only recent tweets are indexed (a typical tweet remains indexed for 6-9 days) and network failures can prevent the application from getting a response to its query. Thus, we will have to make search queries robust to failures. For now, we consider a simplified scenario in which we assume that a response can be reliably obtained from Twitter API. Run the following search that requests up to 100 tweets with a keyword ‘databricks’:
#
# The keywords for the query and the use Twitter Search are described in detail at <a href = "https://dev.twitter.com/docs/api/1.1/get/search/tweets">https://dev.twitter.com/docs/api/1.1/get/search/tweets</a> and <a href = "https://dev.twitter.com/docs/using-search">https://dev.twitter.com/docs/using-search</a>.

# %%
### Code Block 1-8 ###
### You have to run Code Blocks 1-1, 1-2, and 1-3 in order to run Code Block 1-8 

search_results = twitter_api.search.tweets(q='Databricks', count=100)
#Specific tweets matching our query can be extracted as
statuses = search_results['statuses']
#Examine the first tweet among these results:
print json.dumps(statuses[0],indent=1)
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "#Data: Spark 2015 Year In Review - Apache Spark went through a lot in 2015. Get a solid review from Databricks,... https://t.co/dhdYBc7GPO",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 688039693607383040,
#  "favorite_count": 0,
#  "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [],
#   "hashtags": [
#    {
#     "indices": [
#      0,
#      5
#     ],
#     "text": "Data"
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/dhdYBc7GPO",
#     "indices": [
#      115,
#      138
#     ],
#     "expanded_url": "http://ow.ly/3a8jau",
#     "display_url": "ow.ly/3a8jau"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 0,
#  "id_str": "688039693607383040",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 454312928,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/510829346680885248/ARTIGNla.jpeg",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/648119765345677312/EAun5Omu_normal.jpg",
#   "profile_sidebar_fill_color": "C0DFEC",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/uzFHwGbSZl",
#       "indices": [
#        0,
#        23
#       ],
#       "expanded_url": "http://about.me/silvinosantos",
#       "display_url": "about.me/silvinosantos"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 970,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "454312928",
#   "profile_background_color": "000000",
#   "listed_count": 589,
#   "is_translation_enabled": false,
#   "utc_offset": 0,
#   "statuses_count": 102171,
#   "description": "Good stuff really should be sharing, knowledge comes from sharing things, #marketing #networking #strategy #data #services #research #measurement #influence",
#   "friends_count": 777,
#   "location": "Portugal",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/648119765345677312/EAun5Omu_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/454312928/1443203924",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/510829346680885248/ARTIGNla.jpeg",
#   "screen_name": "_silvino_",
#   "lang": "pt",
#   "profile_background_tile": false,
#   "favourites_count": 6533,
#   "name": "Silvino Santos",
#   "notifications": false,
#   "url": "https://t.co/uzFHwGbSZl",
#   "created_at": "Tue Jan 03 21:23:04 +0000 2012",
#   "contributors_enabled": false,
#   "time_zone": "Lisbon",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Fri Jan 15 16:47:00 +0000 2016",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %% [markdown]
# The keywords for the query and the use Twitter Search are described in detail at https://dev.twitter.com/docs/api/1.1/get/search/tweets and https://dev.twitter.com/docs/using-search

# %% [markdown]
# <font color='purple'><b>Question 1-5:</b></font> A complete description of the fields can be found at <a href = "https://dev.twitter.com/docs/platform-objects/tweets">https://dev.twitter.com/docs/platform-objects/tweets</a>, identify the id of the user who posted this tweet afer you run Code Block 1-8, his/her number of friends and followers and the posting date.

# %% [markdown]
# <font color='purple'><b>Write down your answer for Question 1-5 in this cell:</b></font>
#
# <b>id:</b> 688039693607383040 <br>
# <b>friends_count:</b> 777, <br>
# <b>followers_count:</b> 970, <br>
# <b>created_at:</b> Fri Jan 15 16:47:00 +0000 2016

# %% [markdown]
# <p>The results can be saved into a file for subsequent analysis</p>

# %%
### Code Block 1-9 ###

f = open('statuses.json','w') # Check you current folder for statuses.json
json.dump(statuses,f,indent=1)
f.close()

# %% [markdown]
# <p>Next, we look for the most popular tweets in our results. This can be approached through the number of retweets or the number of times the tweet was marked as favorite. Extract the respective counts from the results:</p>

# %%
### Code Block 1-10 ###

rc=[s['retweet_count'] for s in statuses]
fc=[s['favorite_count'] for s in statuses]

# %% [markdown]
# <p>Find the indices of the most retweeted and the most favorite tweet in the results:</p>

# %%
### Code Block 1-11 ###

import numpy
rmax=numpy.argmax(rc)
fmax=numpy.argmax(fc)

### Print the corresponding max numbers and the text of the tweets:
print rc[rmax],statuses[rmax]['text']
print fc[fmax],statuses[fmax]['text']
# Out:
# 63 RT @ApacheSpark: Two Spark MOOCs on edX: Introduction to Big Data with Apache Spark and Scalable Machine Learning https://t.co/OPR0eX8L4A
# 13 Databricks' leadership changes: path to acquisition/IPO? #data #in

# %% [markdown]
# <font color='purple'><b>Question 1-6:</b></font> Indicate these numbers and the texts of the tweets in your submission.

# %% [markdown]
# <font color='purple'><b>Write down your answer for Question 1-6 in this cell:</b></font>
#
# Index: 63 <br>
# Text: RT @ApacheSpark: Two Spark MOOCs on edX: Introduction to Big Data with Apache Spark and Scalable Machine Learning https://t.co/OPR0eX8L4A <br>
#
# Index: 13 <br>
# Text: Databricks' leadership changes: path to acquisition/IPO? #data #in

# %% [markdown]
# <p>The tweets can be examined for the presence of links, user mentions and hashtags:<p>

# %%
### Code Block 1-12 ###

index63h = statuses[rmax]['entities']['hashtags']
index63l = statuses[rmax]['entities']['urls']
index63u = statuses[rmax]['entities']['user_mentions']

index13h = statuses[fmax]['entities']['hashtags']
index13l = statuses[fmax]['entities']['urls']
index13u = statuses[fmax]['entities']['user_mentions']

print "Indexed Tweet 63"
print index63h
print index63l
print index63u

print "Indexed Tweet 13"
print index13h
print index13l
print index13u

##print statuses[rmax]['entities']
##print statuses[fmax]['entities']
# Out:
# Indexed Tweet 63
# []
# [{u'url': u'https://t.co/OPR0eX8L4A', u'indices': [114, 137], u'expanded_url': u'https://databricks.com/blog/2015/06/01/databricks-launches-mooc-data-science-on-spark.html', u'display_url': u'databricks.com/blog/2015/06/0\u2026'}]
# [{u'id': 1551361069, u'indices': [3, 15], u'id_str': u'1551361069', u'screen_name': u'ApacheSpark', u'name': u'Apache Spark'}]
# Indexed Tweet 13
# [{u'indices': [57, 62], u'text': u'data'}, {u'indices': [63, 66], u'text': u'in'}]
# []
# []

# %% [markdown]
# <font color='purple'><b>Question 1-7:</font> In your submission, provide the resulting lists of hastags, links and user mentions with your response.

# %% [markdown]
# <font color='purple'><b>Write down your answer for Question 1-7 in this cell:</b></font>
#
#
#
# <font color='red'><b>Indexed Tweet 63</b><br></font>
# <b>Links</b><br><b>URL</b> https://t.co/OPR0eX8L4AM <b><br>Expanded_URL</b> https://databricks.com/blog/2015/06/01/databricks-launches-mooc-data-science-on-spark.html <b><br>Display URL</b> https://databricks.com/blog/2015/06/0\u2026<br><br><b>User Mentions</b><br>
# <b>uid</b>: 1551361069 <br><b>indices</b>: [3, 15]<br><b>id_str</b>: 1551361069<br> <b>screen_name</b>: ApacheSpark<br> <b>name:</b> Apache Spark
# <font color='red'><b>Indexed Tweet 13</b><br></font>
# <b>Hashtag</b><br><b>Index: </b>[57, 62]<br> <b>text: </b>data<br><b>indices: </b>[63, 66]<br><b>text: </b> in

# %% [markdown]
# <font color='purple'><b>Question 1-8:</font> Using what you learned so far to check the popularity of Hadoop, Spark, Databricks, and Hortonworks On Twitter

# %%
## Provide your code for Question 1-8 if necessary ##

##Hadoop
search_results = twitter_api.search.tweets(q='Hadoop', count=100)
#Specific tweets matching our query can be extracted as
statusesh = search_results['statuses']
#Examine the first tweet among these results:
print json.dumps(statusesh[0],indent=1)

f = open('statusesh.json','w') # Check you current folder for statuses.json
json.dump(statusesh,f,indent=1)
f.close()

rch=[s['retweet_count'] for s in statusesh]
fch=[s['favorite_count'] for s in statusesh] 

import numpy
rhmax=numpy.argmax(rch)
fhmax=numpy.argmax(fch)

print rch[rhmax],statuses[rhmax]['text']
print fch[fhmax],statuses[fhmax]['text']

hindex1h = statuses[rhmax]['entities']['hashtags']
hindex1l = statuses[rhmax]['entities']['urls']
hindex1u = statuses[rhmax]['entities']['user_mentions']

hindex2h = statuses[fhmax]['entities']['hashtags']
hindex2l = statuses[fhmax]['entities']['urls']
hindex2u = statuses[fhmax]['entities']['user_mentions']

print "Indexed Tweet 1"
print hindex1h
print hindex1l
print hindex1u

print "Indexed Tweet 2"
print hindex2h
print hindex2l
print hindex2u

##Spark
search_results = twitter_api.search.tweets(q='Spark', count=100)
#Specific tweets matching our query can be extracted as
statusess = search_results['statuses']
#Examine the first tweet among these results:
print json.dumps(statusess[0],indent=1)

f = open('statusesh.json','w') # Check you current folder for statuses.json
json.dump(statusess,f,indent=1)
f.close()

rcs=[s['retweet_count'] for s in statusess]
fcs=[s['favorite_count'] for s in statusess] 

import numpy
rsmax=numpy.argmax(rcs)
fsmax=numpy.argmax(fcs)

print rcs[rsmax],statuses[rsmax]['text']
print fcs[fsmax],statuses[fsmax]['text']

sindex1h = statuses[rhmax]['entities']['hashtags']
sindex1l = statuses[rhmax]['entities']['urls']
sindex1u = statuses[rhmax]['entities']['user_mentions']

sindex2h = statuses[fhmax]['entities']['hashtags']
sindex2l = statuses[fhmax]['entities']['urls']
sindex2u = statuses[fhmax]['entities']['user_mentions']

print "Indexed Tweet 1"
print sindex1h
print sindex1l
print sindex1u

print "Indexed Tweet 2"
print sindex2h
print sindex2l
print sindex2u

## Hortonworks
search_results = twitter_api.search.tweets(q='Hortonworks', count=100)
#Specific tweets matching our query can be extracted as
statusesho = search_results['statuses']
#Examine the first tweet among these results:
print json.dumps(statusesho[0],indent=1)

f = open('statusesho.json','w') # Check you current folder for statuses.json
json.dump(statusesho,f,indent=1)
f.close()

rcho=[s['retweet_count'] for s in statusesho]
fcho=[s['favorite_count'] for s in statusesho] 

import numpy
rhomax=numpy.argmax(rcho)
fhomax=numpy.argmax(fcho)

print rcho[rhomax],statuses[rhomax]['text']
print fcho[fhomax],statuses[fhomax]['text']

hoindex1h = statuses[rhomax]['entities']['hashtags']
hoindex1l = statuses[rhomax]['entities']['urls']
hoindex1u = statuses[rhomax]['entities']['user_mentions']

hoindex2h = statuses[fhomax]['entities']['hashtags']
hoindex2l = statuses[fhomax]['entities']['urls']
hoindex2u = statuses[fhomax]['entities']['user_mentions']

print "Indexed Tweet 1"
print hoindex1h
print hoindex1l
print hoindex1u

print "Indexed Tweet 2"
print hoindex2h
print hoindex2l
print hoindex2u
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @MondeInformatiq: [PARTENAIRE] #Hadoop : pourquoi faut-il y croire ? #revuedeIT @DellFrance https://t.co/bB8jt8zRVA https://t.co/8VVDsbM\u2026",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 688109342545973248,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 95868974,
#     "indices": [
#      3,
#      19
#     ],
#     "id_str": "95868974",
#     "screen_name": "MondeInformatiq",
#     "name": "LeMondeInformatique"
#    },
#    {
#     "id": 150212556,
#     "indices": [
#      83,
#      94
#     ],
#     "id_str": "150212556",
#     "screen_name": "DELLFrance",
#     "name": "DELL France"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      34,
#      41
#     ],
#     "text": "Hadoop"
#    },
#    {
#     "indices": [
#      72,
#      82
#     ],
#     "text": "revuedeIT"
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/bB8jt8zRVA",
#     "indices": [
#      95,
#      118
#     ],
#     "expanded_url": "http://www.lemondeinformatique.fr/partner_zones/dell-revue-it/article--26.html",
#     "display_url": "lemondeinformatique.fr/partner_zones/\u2026"
#    }
#   ],
#   "media": [
#    {
#     "source_user_id": 95868974,
#     "source_status_id_str": "687574382785343488",
#     "expanded_url": "http://twitter.com/MondeInformatiq/status/687574382785343488/photo/1",
#     "display_url": "pic.twitter.com/8VVDsbMxu9",
#     "url": "https://t.co/8VVDsbMxu9",
#     "media_url_https": "https://pbs.twimg.com/media/CYiObCJWAAAqn-V.jpg",
#     "source_user_id_str": "95868974",
#     "source_status_id": 687574382785343488,
#     "id_str": "686955538257674240",
#     "sizes": {
#      "small": {
#       "h": 250,
#       "resize": "fit",
#       "w": 250
#      },
#      "large": {
#       "h": 250,
#       "resize": "fit",
#       "w": 250
#      },
#      "medium": {
#       "h": 250,
#       "resize": "fit",
#       "w": 250
#      },
#      "thumb": {
#       "h": 150,
#       "resize": "crop",
#       "w": 150
#      }
#     },
#     "indices": [
#      119,
#      140
#     ],
#     "type": "photo",
#     "id": 686955538257674240,
#     "media_url": "http://pbs.twimg.com/media/CYiObCJWAAAqn-V.jpg"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 1,
#  "id_str": "688109342545973248",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "[PARTENAIRE] #Hadoop : pourquoi faut-il y croire ? #revuedeIT @DellFrance https://t.co/bB8jt8zRVA https://t.co/8VVDsbMxu9",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 687574382785343488,
#   "favorite_count": 3,
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 150212556,
#      "indices": [
#       62,
#       73
#      ],
#      "id_str": "150212556",
#      "screen_name": "DELLFrance",
#      "name": "DELL France"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       13,
#       20
#      ],
#      "text": "Hadoop"
#     },
#     {
#      "indices": [
#       51,
#       61
#      ],
#      "text": "revuedeIT"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/bB8jt8zRVA",
#      "indices": [
#       74,
#       97
#      ],
#      "expanded_url": "http://www.lemondeinformatique.fr/partner_zones/dell-revue-it/article--26.html",
#      "display_url": "lemondeinformatique.fr/partner_zones/\u2026"
#     }
#    ],
#    "media": [
#     {
#      "expanded_url": "http://twitter.com/MondeInformatiq/status/687574382785343488/photo/1",
#      "display_url": "pic.twitter.com/8VVDsbMxu9",
#      "url": "https://t.co/8VVDsbMxu9",
#      "media_url_https": "https://pbs.twimg.com/media/CYiObCJWAAAqn-V.jpg",
#      "id_str": "686955538257674240",
#      "sizes": {
#       "small": {
#        "h": 250,
#        "resize": "fit",
#        "w": 250
#       },
#       "large": {
#        "h": 250,
#        "resize": "fit",
#        "w": 250
#       },
#       "medium": {
#        "h": 250,
#        "resize": "fit",
#        "w": 250
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       98,
#       121
#      ],
#      "type": "photo",
#      "id": 686955538257674240,
#      "media_url": "http://pbs.twimg.com/media/CYiObCJWAAAqn-V.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "687574382785343488",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 95868974,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/3409850641/cdee9ce75a0c7a32062a6d0a6bf90e3e_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/9GH4C1DrcS",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.lemondeinformatique.fr/",
#        "display_url": "lemondeinformatique.fr"
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/sIaKFjaPPj",
#        "indices": [
#         62,
#         84
#        ],
#        "expanded_url": "http://ow.ly/x8H3q",
#        "display_url": "ow.ly/x8H3q"
#       }
#      ]
#     }
#    },
#    "followers_count": 20278,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "95868974",
#    "profile_background_color": "C0DEED",
#    "listed_count": 866,
#    "is_translation_enabled": false,
#    "utc_offset": 3600,
#    "statuses_count": 22521,
#    "description": "Toute l'actualit\u00e9 informatique et \u00e9conomique des entreprises. http://t.co/sIaKFjaPPj",
#    "friends_count": 377,
#    "location": "Suresnes",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/3409850641/cdee9ce75a0c7a32062a6d0a6bf90e3e_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/95868974/1398180124",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "MondeInformatiq",
#    "lang": "fr",
#    "profile_background_tile": false,
#    "favourites_count": 114,
#    "name": "LeMondeInformatique",
#    "notifications": false,
#    "url": "http://t.co/9GH4C1DrcS",
#    "created_at": "Thu Dec 10 09:59:14 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Paris",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "fr",
#   "created_at": "Thu Jan 14 09:58:02 +0000 2016",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "fr",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 2228328324,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000824584200/a1078982f3ea6fddda3a11dfb53d41e3_normal.jpeg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 35,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "2228328324",
#   "profile_background_color": "C0DEED",
#   "listed_count": 22,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 396,
#   "description": "Passionn\u00e9 des technologies Web. Freelance Sp\u00e9cialiste en Big Data. JAVA/Cassandra.",
#   "friends_count": 38,
#   "location": "Paris",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000824584200/a1078982f3ea6fddda3a11dfb53d41e3_normal.jpeg",
#   "following": false,
#   "geo_enabled": true,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "WebBakir",
#   "lang": "fr",
#   "profile_background_tile": false,
#   "favourites_count": 65,
#   "name": "Karim BAKIR",
#   "notifications": false,
#   "url": null,
#   "created_at": "Tue Dec 03 13:59:31 +0000 2013",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "fr",
#  "created_at": "Fri Jan 15 21:23:46 +0000 2016",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "fr",
#   "result_type": "recent"
#  }
# }
# 40 My team at Conductor is looking for a Software Engineer, ideally with some distributed computing experience (Hadoop…https://t.co/pnp8ItGkN0
# 2 RT @uber_recruiter: Job Opportunity! Hadoop Developer in Minneapolis, MN https://t.co/NSzGUZK1Op #job #hadoop #bigdata
# Indexed Tweet 1
# []
# [{u'url': u'https://t.co/pnp8ItGkN0', u'indices': [116, 139], u'expanded_url': u'https://lnkd.in/eFYQUfj', u'display_url': u'lnkd.in/eFYQUfj'}]
# []
# Indexed Tweet 2
# [{u'indices': [97, 101], u'text': u'job'}, {u'indices': [102, 109], u'text': u'hadoop'}, {u'indices': [110, 118], u'text': u'bigdata'}]
# [{u'url': u'https://t.co/NSzGUZK1Op', u'indices': [73, 96], u'expanded_url': u'http://bull.hn/l/2P6B9/15', u'display_url': u'bull.hn/l/2P6B9/15'}]
# [{u'id': 22189427, u'indices': [3, 18], u'id_str': u'22189427', u'screen_name': u'uber_recruiter', u'name': u'Andrew Reams'}]
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "@JennaPepworth 5\"6 actually but size don't matter, ill spark ye\ud83d\ude02\ud83d\ude02",
#  "is_quote_status": false,
#  "in_reply_to_status_id": 688109466496049154,
#  "id": 688109705114161153,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 902326970,
#     "indices": [
#      0,
#      14
#     ],
#     "id_str": "902326970",
#     "screen_name": "JennaPepworth",
#     "name": "jenna"
#    }
#   ],
#   "hashtags": [],
#   "urls": []
#  },
#  "in_reply_to_screen_name": "JennaPepworth",
#  "in_reply_to_user_id": 902326970,
#  "retweet_count": 0,
#  "id_str": "688109705114161153",
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 450982842,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/694823484/79b5ce8ce59c3be9a38b4a762b2db1c6.jpeg",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/682362834282528768/Eg2X5t8C_normal.jpg",
#   "profile_sidebar_fill_color": "ECF093",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 312,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "450982842",
#   "profile_background_color": "000000",
#   "listed_count": 6,
#   "is_translation_enabled": false,
#   "utc_offset": 0,
#   "statuses_count": 34940,
#   "description": "19 / Liverpool FC / PSN - imWoggles / Destiny based God / Making plays and going huge / People say the sky is the limit but I want to reach the stars /",
#   "friends_count": 138,
#   "location": "Nottinghamshire, England",
#   "profile_link_color": "DD2E44",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/682362834282528768/Eg2X5t8C_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/450982842/1451404040",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/694823484/79b5ce8ce59c3be9a38b4a762b2db1c6.jpeg",
#   "screen_name": "DangerDoee",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 2837,
#   "name": "Lewis'D",
#   "notifications": false,
#   "url": null,
#   "created_at": "Fri Dec 30 22:16:28 +0000 2011",
#   "contributors_enabled": false,
#   "time_zone": "London",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": "902326970",
#  "lang": "en",
#  "created_at": "Fri Jan 15 21:25:12 +0000 2016",
#  "in_reply_to_status_id_str": "688109466496049154",
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }
# 546 Sunrise Systems Inc: Hadoop Consultant (#BaskingRidge, NJ) https://t.co/0Ezk4hG5Y7 #BusinessMgmt #NettempsJobs #Job #Jobs #Hiring #CareerArc
# 5 RT @uber_recruiter: Job Opportunity! Hadoop Developer in Minneapolis, MN https://t.co/NSzGUZK1Op #job #hadoop #bigdata
# Indexed Tweet 1
# []
# [{u'url': u'https://t.co/pnp8ItGkN0', u'indices': [116, 139], u'expanded_url': u'https://lnkd.in/eFYQUfj', u'display_url': u'lnkd.in/eFYQUfj'}]
# []
# Indexed Tweet 2
# [{u'indices': [97, 101], u'text': u'job'}, {u'indices': [102, 109], u'text': u'hadoop'}, {u'indices': [110, 118], u'text': u'bigdata'}]
# [{u'url': u'https://t.co/NSzGUZK1Op', u'indices': [73, 96], u'expanded_url': u'http://bull.hn/l/2P6B9/15', u'display_url': u'bull.hn/l/2P6B9/15'}]
# [{u'id': 22189427, u'indices': [3, 18], u'id_str': u'22189427', u'screen_name': u'uber_recruiter', u'name': u'Andrew Reams'}]
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @alanshoeford: Hortonworks launches big data partner programme https://t.co/G8CTB5XTJ5 #BigData",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 688108582433198081,
#  "favorite_count": 0,
#  "source": "<a href=\"https://gamedevbrain.wordpress.com/\" rel=\"nofollow\">BigDataTweetBot</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 2370983803,
#     "indices": [
#      3,
#      16
#     ],
#     "id_str": "2370983803",
#     "screen_name": "alanshoeford",
#     "name": "Alan Shoeford"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      90,
#      98
#     ],
#     "text": "BigData"
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/G8CTB5XTJ5",
#     "indices": [
#      66,
#      89
#     ],
#     "expanded_url": "http://www.channelbiz.co.uk/2016/01/15/hortonworks-launches-big-data-partner-programme/",
#     "display_url": "channelbiz.co.uk/2016/01/15/hor\u2026"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 1,
#  "id_str": "688108582433198081",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "Hortonworks launches big data partner programme https://t.co/G8CTB5XTJ5 #BigData",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 688106065062301696,
#   "favorite_count": 1,
#   "source": "<a href=\"http://www.google.com\" rel=\"nofollow\">Alan Shoeford Tweets</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       72,
#       80
#      ],
#      "text": "BigData"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/G8CTB5XTJ5",
#      "indices": [
#       48,
#       71
#      ],
#      "expanded_url": "http://www.channelbiz.co.uk/2016/01/15/hortonworks-launches-big-data-partner-programme/",
#      "display_url": "channelbiz.co.uk/2016/01/15/hor\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "688106065062301696",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2370983803,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/440605240715268096/M6rJtOSW_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 1445,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2370983803",
#    "profile_background_color": "C0DEED",
#    "listed_count": 645,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 14363,
#    "description": "Internet junky turned marketing executive. Love #ContentMarketing, #BigData and #InternetOfThings. Surfer, beer drinker, amateur DJ.",
#    "friends_count": 765,
#    "location": "Los Angeles",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/440605240715268096/M6rJtOSW_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2370983803/1400247685",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "alanshoeford",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 19,
#    "name": "Alan Shoeford",
#    "notifications": false,
#    "url": null,
#    "created_at": "Mon Mar 03 21:43:33 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Fri Jan 15 21:10:44 +0000 2016",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 3356052532,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/616793252524650496/bQbxJqmz_normal.jpg",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 6933,
#   "profile_sidebar_border_color": "C0DEED",
#   "id_str": "3356052532",
#   "profile_background_color": "C0DEED",
#   "listed_count": 7242,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 538757,
#   "description": "I retweet #bigdata follow to get a feed of all that is tweeted about this subject. createdby @magicrat_larry",
#   "friends_count": 243,
#   "location": "",
#   "profile_link_color": "0084B4",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/616793252524650496/bQbxJqmz_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "BigDataTweetBot",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 0,
#   "name": "Big Data Tweet",
#   "notifications": false,
#   "url": null,
#   "created_at": "Fri Jul 03 01:30:20 +0000 2015",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": true,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Fri Jan 15 21:20:45 +0000 2016",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }
# 23 Forget the FUD! Get Data: Which do you choose for a #Data lake? #Hadoop or an in-memory database? https://t.co/hZ9fX0zBwU
# 5 RT @ryanrod42: #bigdata Survey: Big Data Goes Mainstream: submitted by  piterpolk  [link] [comment] https://t.co/SAIf0fGTWu #hadoop
# Indexed Tweet 1
# []
# [{u'url': u'https://t.co/pnp8ItGkN0', u'indices': [116, 139], u'expanded_url': u'https://lnkd.in/eFYQUfj', u'display_url': u'lnkd.in/eFYQUfj'}]
# []
# Indexed Tweet 2
# [{u'indices': [97, 101], u'text': u'job'}, {u'indices': [102, 109], u'text': u'hadoop'}, {u'indices': [110, 118], u'text': u'bigdata'}]
# [{u'url': u'https://t.co/NSzGUZK1Op', u'indices': [73, 96], u'expanded_url': u'http://bull.hn/l/2P6B9/15', u'display_url': u'bull.hn/l/2P6B9/15'}]
# [{u'id': 22189427, u'indices': [3, 18], u'id_str': u'22189427', u'screen_name': u'uber_recruiter', u'name': u'Andrew Reams'}]

# %% [markdown]
# <font color='purple'><b>Write down your analysis for Question 1-8 in this cell:</b></font>
#
# Based on the output below, we can see that the terms "Hadoop", "Spark" and "Hortonworks" are fairly popular and frequently used terms. All 3 of the results were tweeted within the last 30 minutes, and those who tweeted them had a wide range of friends and followers from as low as 35 to as high as 6933. Usage of the terms ranged from tweeters posting for job opportunities, as well as well as just general news within the Big Data landscape. Unsurprisingly, these terms generally are found in the same kind of tweets, as one of the most popular tweets for Hadoop (the uber_recruiter tweet), was also found for Spark. Other big data terms are also used in conjunction with these terms.
#
# Hadoop Output
#
# id: 2228328324
# friends_count: 35
# followers_count: 38
# created_at: Fri Jan 15 21:23:46 +0000 201
#
# Index: 40
# Text: My team at Conductor is looking for a Software Engineer, ideally with some distributed computing experience (Hadoop…https://t.co/pnp8ItGkN0
# Index: 2
# Text: RT @uber_recruiter: Job Opportunity! Hadoop Developer in Minneapolis, MN https://t.co/NSzGUZK1Op #job #hadoop #bigdata
#
# Links: [{u'url': u'https://t.co/pnp8ItGkN0', u'indices': [116, 139], u'expanded_url': u'https://lnkd.in/eFYQUfj', u'display_url': u'lnkd.in/eFYQUfj'}]
# User Mentions:
# Hashtags:
#
# Links: [{u'url': u'https://t.co/NSzGUZK1Op', u'indices': [73, 96], u'expanded_url': u'http://bull.hn/l/2P6B9/15', u'display_url': u'bull.hn/l/2P6B9/15'}]
# User Mentions: [{u'id': 22189427, u'indices': [3, 18], u'id_str': u'22189427', u'screen_name': u'uber_recruiter', u'name': u'Andrew Reams'}]
# Hashtags: [{u'indices': [97, 101], u'text': u'job'}, {u'indices': [102, 109], u'text': u'hadoop'}, {u'indices': [110, 118], u'text': u'bigdata'}]
#
# Spark Output
#
# id: 688109705114161153
# friends_count: 138
# followers_count: 312
# created_at: Fri Jan 15 21:25:12 +0000 2016
#
# Index: 546
# Text: Sunrise Systems Inc: Hadoop Consultant (#BaskingRidge, NJ) https://t.co/0Ezk4hG5Y7 #BusinessMgmt #NettempsJobs #Job #Jobs #Hiring #CareerArc
# Index: 5
# Text: RT @uber_recruiter: Job Opportunity! Hadoop Developer in Minneapolis, MN https://t.co/NSzGUZK1Op #job #hadoop #bigdata
#
# Links: [{u'url': u'https://t.co/pnp8ItGkN0', u'indices': [116, 139], u'expanded_url': u'https://lnkd.in/eFYQUfj', u'display_url': u'lnkd.in/eFYQUfj'}]
# User Mentions:
# Hashtags:
#
# Links: [{u'url': u'https://t.co/NSzGUZK1Op', u'indices': [73, 96], u'expanded_url': u'http://bull.hn/l/2P6B9/15', u'display_url': u'bull.hn/l/2P6B9/15'}]
# User Mentions: [{u'id': 22189427, u'indices': [3, 18], u'id_str': u'22189427', u'screen_name': u'uber_recruiter', u'name': u'Andrew Reams'}]
# Hashtags: [{u'indices': [97, 101], u'text': u'job'}, {u'indices': [102, 109], u'text': u'hadoop'}, {u'indices': [110, 118], u'text': u'bigdata'}]
#
# Hortonworks Output
#
# id: 688108582433198081
# friends_count: 243
# followers_count: 6933
# created_at: Fri Jan 15 21:20:45 +0000 2016
#
# Index: 23
# Text: Forget the FUD! Get Data: Which do you choose for a #Data lake? #Hadoop or an in-memory database? https://t.co/hZ9fX0zBwU
# Index: 5
# Text: RT @ryanrod42: #bigdata Survey: Big Data Goes Mainstream: submitted by  piterpolk  [link] [comment] https://t.co/SAIf0fGTWu #hadoop
#
# Links: [{u'url': u'https://t.co/pnp8ItGkN0', u'indices': [116, 139], u'expanded_url': u'https://lnkd.in/eFYQUfj', u'display_url': u'lnkd.in/eFYQUfj'}]
# User Mentions:
# Hashtags:
#
# Links: [{u'url': u'https://t.co/NSzGUZK1Op', u'indices': [73, 96], u'expanded_url': u'http://bull.hn/l/2P6B9/15', u'display_url': u'bull.hn/l/2P6B9/15'}]
# User Mentions:[{u'id': 22189427, u'indices': [3, 18], u'id_str': u'22189427', u'screen_name': u'uber_recruiter', u'name': u'Andrew Reams'}]
# Hashtags:[{u'indices': [97, 101], u'text': u'job'}, {u'indices': [102, 109], u'text': u'hadoop'}, {u'indices': [110, 118], u'text': u'bigdata'}]
